# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # NLP Basics Assessment

# %% [markdown]
# For this assessment we'll be using the short story [_An Occurrence at Owl Creek Bridge_](https://en.wikipedia.org/wiki/An_Occurrence_at_Owl_Creek_Bridge) by Ambrose Bierce (1890). <br>The story is in the public domain; the text file was obtained from [Project Gutenberg](https://www.gutenberg.org/ebooks/375.txt.utf-8).

# %%
# RUN THIS CELL to perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# **1. Create a Doc object from the file `owlcreek.txt`**<br>
# > HINT: Use `with open('../TextFiles/owlcreek.txt') as f:`

# %%
with open("TextFiles/owlcreek.txt") as f:
    text = f.readlines()
    string = ''.join([str(t) for t in text])
doc = nlp(string)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[55], line 2
#       1 with open("TextFiles/owlcreek.txt") as f:
# ----> 2     text = f.readlines()
#       3     string = ''.join([str(t) for t in text])
#       4 doc = nlp(string)
#
# File ~\anaconda3\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 1698: character maps to <undefined>

# %%
# Run this cell to verify it worked:

doc[:36]

# %% [markdown]
# **2. How many tokens are contained in the file?**

# %%
tokens = 0
for token in doc:
    tokens+= 1
print(tokens)

# %% [markdown]
# **3. How many sentences are contained in the file?**<br>HINT: You'll want to build a list first!

# %%
sent_count = 0
for sent in doc.sents:
    sent_count+=1
print(sent_count)
# Out:
# 204

# %% [markdown]
# **4. Print the second sentence in the document**<br> HINT: Indexing starts at zero, and the title counts as the first sentence.

# %%
for sent_i, sent in enumerate(doc.sents):
    if sent_i == 1:
        print(sent)
# Out:
# The man's hands were behind
# his back, the wrists bound with a cord.

# %% [markdown]
# ** 5. For each token in the sentence above, print its `text`, `POS` tag, `dep` tag and `lemma`<br>
# CHALLENGE: Have values line up in columns in the print output.**

# %%
# NORMAL SOLUTION:
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.dep_)
# Out:
# AN an DET det
# OCCURRENCE occurrence NOUN nmod
# AT AT PROPN prep
# OWL OWL PROPN compound
# CREEK CREEK PROPN compound
# BRIDGE BRIDGE PROPN ROOT
#
#
#
#
#  SPACE dep
# by by ADP prep
# Ambrose Ambrose PROPN compound
# Bierce Bierce PROPN pobj
#
#
#
#
#  SPACE dep
# I I PRON punct
#
#
#
#
#  SPACE dep
# A a DET det
# man man NOUN nsubj
# stood stand VERB relcl
# upon upon SCONJ prep
# a a DET det
# railroad railroad NOUN compound
# bridge bridge NOUN pobj
# in in ADP prep
# northern northern ADJ amod
# Alabama Alabama PROPN pobj
# , , PUNCT punct
# looking look VERB advcl
# down down ADV advmod
#
#
#  SPACE dep
# into into ADP prep
# the the DET det
# swift swift ADJ amod
# water water NOUN pobj
# twenty twenty NUM nummod
# feet foot NOUN npadvmod
# below below ADV advmod
# . . PUNCT punct
#     SPACE dep
# The the DET det
# man man NOUN poss
# 's 's PART case
# hands hand NOUN nsubj
# were be AUX ROOT
# behind behind ADP prep
#
#
#  SPACE dep
# his his PRON poss
# ...

# %%
# CHALLENGE SOLUTION:
for token in doc:
    print(f"{token.text:{10}} {token.pos_:{8}} {token.tag_:{6}} {token.lemma_:{7}}")
# Out:
# AN         DET      DT     an
# OCCURRENCE NOUN     NN     occurrence
# AT         PROPN    NNP    AT
# OWL        PROPN    NNP    OWL
# CREEK      PROPN    NNP    CREEK
# BRIDGE     PROPN    NNP    BRIDGE
#
#
#          SPACE    _SP
#
#
# by         ADP      IN     by
# Ambrose    PROPN    NNP    Ambrose
# Bierce     PROPN    NNP    Bierce
#
#
#          SPACE    _SP
#
#
# I          PRON     PRP    I
#
#
#          SPACE    _SP
#
#
# A          DET      DT     a
# man        NOUN     NN     man
# stood      VERB     VBD    stand
# upon       SCONJ    IN     upon
# a          DET      DT     a
# railroad   NOUN     NN     railroad
# bridge     NOUN     NN     bridge
# in         ADP      IN     in
# northern   ADJ      JJ     northern
# Alabama    PROPN    NNP    Alabama
# ,          PUNCT    ,      ,
# looking    VERB     VBG    look
# down       ADV      RB     down
#
#           SPACE    _SP
#
# into       ADP      IN     into
# the        DET      DT     the
# ...

# %% [markdown]
# **6. Write a matcher called 'Swimming' that finds both occurrences of the phrase "swimming vigorously" in the text**<br>
# HINT: You should include an `'IS_SPACE': True` pattern between the two words!

# %%
# Import the Matcher library:

from spacy.matcher import Matcher
Swimming = Matcher(nlp.vocab)

# %%
# Create a pattern and add it to matcher:
pattern1 = [{'LOWER': 'swimming vigorously'},{'IS_SPACE': True}]
pattern2 = [{'LOWER': 'swimming'}, {'LOWER': 'vigorously'}]

Swimming.add("swimming vigorously",[pattern1,pattern2])

# %%
# Create a list of matches called "found_matches" and print the list:
found_matches = Swimming(doc)
print(found_matches)
# Out:
# []

# %% [markdown]
# **7. Print the text surrounding each found match**

# %%
# Out:
# []

# %%
# Out:
# over his shoulder; he was now swimming
# vigorously with the current.

# %% [markdown]
# **EXTRA CREDIT:<br>Print the *sentence* that contains each found match**

# %%
# Out:
# By diving I could evade the bullets and, swimming
# vigorously, reach the bank, take to the woods and get away home.

# %%
# Out:
# The hunted man saw all this over his shoulder; he was now swimming
# vigorously with the current.

# %% [markdown]
# ### Great Job!
